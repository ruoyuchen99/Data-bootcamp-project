# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
pd.set_option('display.max_rows', None)
mpl.style.use('seaborn')

# %% [markdown]
# # Income based visualization
# # 1. WGI data
#
# ## Low income countries

# %%
# import data for low income countries
low = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/Low_inc_WGI.csv')

#cleaning and reshaping data for low income countries
low=low.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in low.columns[4:]:
    low[i]=pd.to_numeric(low[i],errors='coerce')
    
low=low.groupby('Series Name').mean()

low=low.transpose()
low=low.rename(columns={'Control of Corruption: Estimate':'corruption','Government Effectiveness: Estimate':'effectiveness',
                  'Political Stability and Absence of Violence/Terrorism: Estimate':'stability','Regulatory Quality: Estimate':'regulation',
                  'Rule of Law: Estimate':'law','Voice and Accountability: Estimate':'voice','Fixed broadband subscriptions (per 100 people)':'broadband'})

# plot 6 WGI indicators for low income countries over time
fig, ax = plt.subplots()
low.plot(ax=ax,figsize=(10,8))
ax.set_title('Low income WGI',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# ## High income countries

# %%
# import data for high income countries
high = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/Hi_inc_WGI.csv')

#cleaning and reshaping data for high income countries
high=high.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in high.columns[4:]:
    high[i]=pd.to_numeric(high[i],errors='coerce')
    
high=high.groupby('Series Name').mean()
high=high.transpose()
high=high.rename(columns={'Control of Corruption: Estimate':'corruption','Government Effectiveness: Estimate':'effectiveness',
                  'Political Stability and Absence of Violence/Terrorism: Estimate':'stability','Regulatory Quality: Estimate':'regulation',
                  'Rule of Law: Estimate':'law','Voice and Accountability: Estimate':'voice','Fixed broadband subscriptions (per 100 people)':'broadband'})

# plot 6 WGI indicators for high income countries over time
fig, ax = plt.subplots()
high.plot(ax=ax,figsize=(10,8))
ax.set_title('High income WGI',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# ## Lower middle income countries

# %%
# import data for lower middle income countries
lo_mid = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/Lo_mid_WGI.csv')

#cleaning and reshaping data for lower middle income countries
lo_mid=lo_mid.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in lo_mid.columns[4:]:
    lo_mid[i]=pd.to_numeric(lo_mid[i],errors='coerce')
    
lo_mid=lo_mid.groupby('Series Name').mean()
lo_mid=lo_mid.transpose()
lo_mid=lo_mid.rename(columns={'Control of Corruption: Estimate':'corruption','Government Effectiveness: Estimate':'effectiveness',
                  'Political Stability and Absence of Violence/Terrorism: Estimate':'stability','Regulatory Quality: Estimate':'regulation',
                  'Rule of Law: Estimate':'law','Voice and Accountability: Estimate':'voice','Fixed broadband subscriptions (per 100 people)':'broadband'})

# plot 6 WGI indicators for lower middle income countries over time
fig, ax = plt.subplots()
lo_mid.plot(ax=ax,figsize=(10,8))
ax.set_title('Lower middle income WGI',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# ## Upper middle income countries

# %%
# import data for upper middle income countries
up_mid = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/up_mid_WGI.csv')

#cleaning and reshaping data for upper middle income countries
up_mid=up_mid.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in up_mid.columns[4:]:
    up_mid[i]=pd.to_numeric(up_mid[i],errors='coerce')
    
up_mid=up_mid.groupby('Series Name').mean()
up_mid=up_mid.transpose()
up_mid=up_mid.rename(columns={'Control of Corruption: Estimate':'corruption','Government Effectiveness: Estimate':'effectiveness',
                  'Political Stability and Absence of Violence/Terrorism: Estimate':'stability','Regulatory Quality: Estimate':'regulation',
                  'Rule of Law: Estimate':'law','Voice and Accountability: Estimate':'voice','Fixed broadband subscriptions (per 100 people)':'broadband'})

# plot 6 WGI indicators for upper middle income countries over time
fig, ax = plt.subplots()
up_mid.plot(ax=ax,figsize=(10,8))
ax.set_title('Upper middle income WGI',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# # Differences among income groups

# %%
fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(3,2)
fig.set_size_inches(10,15)

low['corruption'].plot(ax=ax1)
high['corruption'].plot(ax=ax1)
lo_mid['corruption'].plot(ax=ax1)
up_mid['corruption'].plot(ax=ax1)

low['effectiveness'].plot(ax=ax2)
high['effectiveness'].plot(ax=ax2)
lo_mid['effectiveness'].plot(ax=ax2)
up_mid['effectiveness'].plot(ax=ax2)

low['stability'].plot(ax=ax3)
high['stability'].plot(ax=ax3)
lo_mid['stability'].plot(ax=ax3)
up_mid['stability'].plot(ax=ax3)

low['regulation'].plot(ax=ax4)
high['regulation'].plot(ax=ax4)
lo_mid['regulation'].plot(ax=ax4)
up_mid['regulation'].plot(ax=ax4)

low['law'].plot(ax=ax5)
high['law'].plot(ax=ax5)
lo_mid['law'].plot(ax=ax5)
up_mid['law'].plot(ax=ax5)

low['voice'].plot(ax=ax6)
high['voice'].plot(ax=ax6)
lo_mid['voice'].plot(ax=ax6)
up_mid['voice'].plot(ax=ax6)

ax4.legend(['low_inc','high_inc','low_mid','hi_mid'], bbox_to_anchor=(1,1),prop={"size":15})

ax1.set_title('corruption',size=15,fontweight='bold')
ax2.set_title('effectiveness',size=15,fontweight='bold')
ax3.set_title('stability',size=15,fontweight='bold')
ax4.set_title('regulation',size=15,fontweight='bold')
ax5.set_title('law',size=15,fontweight='bold')
ax6.set_title('voice',size=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'voice')

# %% [markdown]
# # 2. ICT Data
#
# ## Low income countries

# %%
# import data for low income countries
loinc = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/loinc_ict.csv')

#cleaning and reshaping data for low income countries
loinc=loinc.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in loinc.columns[4:]:
    loinc[i]=pd.to_numeric(loinc[i],errors='coerce')
    
loinc=loinc.groupby('Series Name').mean()

loinc=loinc.transpose()
loinc=loinc.rename(columns={'Fixed broadband subscriptions (per 100 people)':'broadband',
                'Individuals using the Internet (% of population)':'user',
                  'Mobile cellular subscriptions (per 100 people)':'mobile','Secure Internet servers (per 1 million people)':'server'})

# plot 4 ICT indicators for upper middle income countries over time
fig, ax = plt.subplots()
loinc.plot(ax=ax,figsize=(10,8))
ax.set_title('Low income ICT',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# ## High income countries

# %%
# import data for high income countries
high1 = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/hiinc_ict.csv')

#cleaning and reshaping data for high income countries
high1=high1.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})
for i in high1.columns[4:]:
    high1[i]=pd.to_numeric(high1[i],errors='coerce')
    
high1=high1.groupby('Series Name').mean()

high1=high1.transpose()
high1=high1.rename(columns={'Fixed broadband subscriptions (per 100 people)':'broadband',
                  'Individuals using the Internet (% of population)':'user',
                  'Mobile cellular subscriptions (per 100 people)':'mobile','Secure Internet servers (per 1 million people)':'server'})

# plot 4 ICT indicators for high income countries over time

fig, ax = plt.subplots()
high1.plot(ax=ax,figsize=(10,8))
ax.set_title('High income ICT',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# ## Lower middle income countries

# %%
# import data for lower middle income countries
lo_mid1 = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/lomid_ict.csv')

#cleaning and reshaping data for lower middle income countries
lo_mid1=lo_mid1.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in lo_mid1.columns[4:]:
    lo_mid1[i]=pd.to_numeric(lo_mid1[i],errors='coerce')
    
lo_mid1=lo_mid1.groupby('Series Name').mean()

lo_mid1=lo_mid1.transpose()
lo_mid1=lo_mid1.rename(columns={'Fixed broadband subscriptions (per 100 people)':'broadband',
                  'Individuals using the Internet (% of population)':'user',
                  'Mobile cellular subscriptions (per 100 people)':'mobile','Secure Internet servers (per 1 million people)':'server'})

# plot 4 ICT indicators for lower middle income countries over time

fig, ax = plt.subplots()
lo_mid1.plot(ax=ax,figsize=(10,8))
ax.set_title('Lower middle income ICT',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# ## Upper middle income

# %%
# import data for upper middle income countries
up_mid1 = pd.read_csv('https://raw.githubusercontent.com/ruoyuchen99/Data-bootcamp-project/master/upmid_ict.csv')

#cleaning and reshaping data for upper middle income countries
up_mid1=up_mid1.rename(columns={'2004 [YR2004]':2004,'2005 [YR2005]':2005,'2006 [YR2006]':2006,'2007 [YR2007]':2007,'2008 [YR2008]':2008,\
                        '2009 [YR2009]':2009,'2010 [YR2010]':2010,'2011 [YR2011]':2011,'2012 [YR2012]':2012,\
                        '2013 [YR2013]':2013,'2014 [YR2014]':2014,'2015 [YR2015]':2015,\
                        '2016 [YR2016]':2016,'2017 [YR2017]':2017,'2018 [YR2018]':2018})

for i in up_mid1.columns[4:]:
    up_mid1[i]=pd.to_numeric(up_mid1[i],errors='coerce')
    
up_mid1=up_mid1.groupby('Series Name').mean()

up_mid1=up_mid1.transpose()
up_mid1=up_mid1.rename(columns={'Fixed broadband subscriptions (per 100 people)':'broadband',
                  'ICT service exports (BoP, current US$)':'export','Individuals using the Internet (% of population)':'user',
                  'Mobile cellular subscriptions (per 100 people)':'mobile','Secure Internet servers (per 1 million people)':'server'})

# plot 4 ICT indicators for high income countries over time

fig, ax = plt.subplots()
up_mid1.plot(ax=ax,figsize=(10,8))
ax.set_title('Upper middle income ICT',size=24,fontweight='bold')
ax.set_xlabel('Year',size=16)

ax.legend(bbox_to_anchor=(1,1),prop={"size":15})

# %% [markdown]
# # Differences among income groups

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2)
fig.set_size_inches(10,10)

loinc['broadband'].plot(ax=ax1)
high1['broadband'].plot(ax=ax1)
lo_mid1['broadband'].plot(ax=ax1)
up_mid1['broadband'].plot(ax=ax1)

loinc['user'].plot(ax=ax2)
high1['user'].plot(ax=ax2)
lo_mid1['user'].plot(ax=ax2)
up_mid1['user'].plot(ax=ax2)

loinc['mobile'].plot(ax=ax3)
high1['mobile'].plot(ax=ax3)
lo_mid1['mobile'].plot(ax=ax3)
up_mid1['mobile'].plot(ax=ax3)

loinc['server'].plot(ax=ax4)
high1['server'].plot(ax=ax4)
lo_mid1['server'].plot(ax=ax4)
up_mid1['server'].plot(ax=ax4)


ax4.legend(['low_inc','high_inc','low_mid','hi_mid'], bbox_to_anchor=(1,1),prop={"size":15})

ax1.set_title('broadband',size=15,fontweight='bold')
ax2.set_title('user',size=15,fontweight='bold')
ax3.set_title('mobile',size=15,fontweight='bold')
ax4.set_title('server',size=15,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'server')
